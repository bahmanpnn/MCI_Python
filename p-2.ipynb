# %%
x=input("please enter a number")

my_list=list(x)
for number in my_list:
    print(f"{number}:{number*int(number)}")
# Out:
# please enter a number 50943
# 5:55555
# 0:
# 9:999999999
# 4:4444
# 3:333
